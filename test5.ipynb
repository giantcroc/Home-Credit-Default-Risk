# %%
import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold,cross_val_score
from lightgbm import LGBMClassifier
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')
from bayes_opt import BayesianOptimization
from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier, 
                              GradientBoostingClassifier, ExtraTreesClassifier)
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import gc
gc.enable()

# %%
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    print (categorical_columns)
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

print('Read data and test')
data = pd.read_csv('./input/application_train.csv')
test = pd.read_csv('./input/application_test.csv')
print('Shapes : ', data.shape, test.shape)

y = data['TARGET']
del data['TARGET']
gc.collect()
all_data = pd.concat((data, test)).reset_index(drop=True)

inc_by_org = all_data[['AMT_INCOME_TOTAL', 'ORGANIZATION_TYPE']].groupby('ORGANIZATION_TYPE').median()['AMT_INCOME_TOTAL']
all_data['NEW_INC_BY_ORG'] = all_data['ORGANIZATION_TYPE'].map(inc_by_org)

for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
    all_data[bin_feature], uniques = pd.factorize(all_data[bin_feature])
all_data, cat_cols = one_hot_encoder(all_data)
print all_data.shape
# Some simple new features (percentages)
#all_data['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)
n_data = data.shape[0]

all_data['DAYS_EMPLOYED_PERC'] = all_data['DAYS_EMPLOYED'] / all_data['DAYS_BIRTH']
all_data['INCOME_CREDIT_PERC'] = all_data['AMT_INCOME_TOTAL'] / all_data['AMT_CREDIT']
all_data['INCOME_PER_PERSON'] = all_data['AMT_INCOME_TOTAL'] / all_data['CNT_FAM_MEMBERS']
all_data['ANNUITY_INCOME_PERC'] = all_data['AMT_ANNUITY'] / all_data['AMT_INCOME_TOTAL']
all_data['PAYMENT_RATE'] = all_data['AMT_CREDIT'] / all_data['AMT_ANNUITY']

print all_data.shape
del data,test
gc.collect()

bureau = pd.read_csv('./input/bureau.csv')
buro_bal = pd.read_csv('./input/bureau_balance.csv')
buro_bal, bb_cat = one_hot_encoder(buro_bal)
bureau, bureau_cat = one_hot_encoder(bureau)
bb_aggregations = {'MONTHS_BALANCE': ['min', 'max','mean']}
for col in bb_cat:
    bb_aggregations[col] = ['mean']
    bb_agg = buro_bal.groupby('SK_ID_BUREAU').agg(bb_aggregations)
bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
bb_agg['BB_COUNT'] = buro_bal.groupby('SK_ID_BUREAU').size()
print bb_agg.shape
bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
bureau.drop(columns= 'SK_ID_BUREAU', inplace= True)
del buro_bal,bb_agg
gc.collect()

num_aggregations = {
    'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
    'CREDIT_DAY_OVERDUE': ['max', 'mean'],
    'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
    'AMT_CREDIT_MAX_OVERDUE': ['mean'],
    'CNT_CREDIT_PROLONG': ['sum','mean'],
    'AMT_CREDIT_SUM': ['max','mean', 'sum'],
    'AMT_CREDIT_SUM_DEBT': ['max','mean', 'sum'],
    'AMT_CREDIT_SUM_OVERDUE': ['mean'],
    'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
    'DAYS_CREDIT_UPDATE': ['min','max','mean'],
    'AMT_ANNUITY': ['max', 'mean'],
    'MONTHS_BALANCE_MIN': ['min'],
    'MONTHS_BALANCE_MAX': ['max'],
    'MONTHS_BALANCE_MEAN': ['mean'],
    'BB_COUNT': ['mean', 'sum']
}
cat_aggregations = {}
for cat in bureau_cat: cat_aggregations[cat] = ['mean']
for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
bureau_agg = bureau.groupby('SK_ID_CURR').agg(dict(num_aggregations, **cat_aggregations))
bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
bureau_agg['BURO_COUNT'] = bureau.groupby('SK_ID_CURR').size()
print bureau_agg.shape

active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
active_agg.columns = pd.Index(['ACT_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
active_agg['ACT_COUNT'] = active.groupby('SK_ID_CURR').size()
bureau_agg = bureau_agg.reset_index().join(active_agg, how='left', on='SK_ID_CURR')
print bureau_agg.shape
del active, active_agg
gc.collect()

closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
closed_agg = closed.groupby('SK_ID_CURR').agg(dict({'DAYS_ENDDATE_FACT': ['min','max','mean']},**num_aggregations))
closed_agg.columns = pd.Index(['CLS_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
closed_agg['CLS_COUNT'] = closed.groupby('SK_ID_CURR').size()
bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
print bureau_agg.shape
del closed, closed_agg, bureau
gc.collect()

all_data = all_data.merge(bureau_agg, how='left', on='SK_ID_CURR')
print all_data.shape
del bureau_agg
gc.collect()

prev = pd.read_csv('./input/previous_application.csv')
prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
# Days 365.243 values -> nan
prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
# Add feature: value ask / value received percentage
prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
# Previous applications numeric features
num_aggregations = {
    'AMT_ANNUITY': ['min','max', 'mean'],
    'AMT_APPLICATION': ['min','max', 'mean'],
    'AMT_CREDIT': ['min','max', 'mean'],
    'APP_CREDIT_PERC': ['min', 'max', 'mean', 'var'],
    'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
    'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
    'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
    'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
    'DAYS_DECISION': ['min', 'max', 'mean'],
    'SELLERPLACE_AREA': ['min', 'max', 'mean'],
    'DAYS_FIRST_DRAWING': ['min', 'max', 'mean'],
    'DAYS_FIRST_DUE': ['min', 'max', 'mean'],
    'DAYS_LAST_DUE_1ST_VERSION': ['min', 'max', 'mean'],
    'DAYS_LAST_DUE': ['min', 'max', 'mean'],
    'DAYS_TERMINATION': ['min', 'max', 'mean'],
    'CNT_PAYMENT': ['mean', 'sum']
}
# Previous applications categorical features
cat_aggregations = {}
for cat in cat_cols:
    cat_aggregations[cat] = ['mean']

prev_agg = prev.groupby('SK_ID_CURR').agg(dict(num_aggregations, **cat_aggregations))
prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
prev_agg['PREV_COUNT'] = prev.groupby('SK_ID_CURR').size()
print prev_agg.shape
# Previous Applications: Approved Applications - only numerical features
approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
approved_agg.columns = pd.Index(['APR_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
approved_agg['APR_COUNT'] = approved.groupby('SK_ID_CURR').size()
prev_agg = prev_agg.reset_index().join(approved_agg, how='left', on='SK_ID_CURR')
print prev_agg.shape
# Previous Applications: Refused Applications - only numerical features
refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
refused_agg.columns = pd.Index(['REF_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
refused_agg['REF_COUNT'] = refused.groupby('SK_ID_CURR').size()
prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
print prev_agg.shape
del refused, refused_agg, approved, approved_agg, prev
gc.collect()

all_data = all_data.merge(prev_agg, how='left', on='SK_ID_CURR')
print all_data.shape
del prev_agg
gc.collect()

pos = pd.read_csv('./input/POS_CASH_balance.csv')
pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
# Features
aggregations = {
    'MONTHS_BALANCE': ['min','max', 'mean'],
    'CNT_INSTALMENT': ['sum', 'mean'],
    'SK_DPD': ['sum','max','min','mean'],
    'SK_DPD_DEF': ['sum','max', 'min','mean']
}
for cat in cat_cols:
    aggregations[cat] = ['mean']

pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
# Count pos cash accounts
pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
print pos_agg.shape
del pos
gc.collect()

all_data = all_data.join(pos_agg, how='left', on='SK_ID_CURR')
print all_data.shape
del pos_agg
gc.collect()

ins = pd.read_csv('./input/installments_payments.csv')
ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
# Percentage and difference paid in each installment (amount paid and installment value)
ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
# Days past due and days before due (no negative values)
ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
# Features: Perform aggregations
aggregations = {
    'NUM_INSTALMENT_VERSION': ['nunique'],
    'DPD': ['max', 'mean', 'sum'],
    'DBD': ['max', 'mean', 'sum'],
    'PAYMENT_PERC': ['max', 'mean', 'sum', 'var'],
    'PAYMENT_DIFF': ['max', 'mean', 'sum', 'var'],
    'AMT_INSTALMENT': ['max', 'mean', 'sum'],
    'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
    'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum'],
    'DAYS_INSTALMENT': ['max', 'mean', 'sum']
}
for cat in cat_cols:
    aggregations[cat] = ['mean']
ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
ins_agg.columns = pd.Index(['INS_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
# Count installments accounts
ins_agg['INS_COUNT'] = ins.groupby('SK_ID_CURR').size()
print ins_agg.shape
del ins
gc.collect()

all_data = all_data.join(ins_agg, how='left', on='SK_ID_CURR')
print all_data.shape
del ins_agg
gc.collect()

cc = pd.read_csv('./input/credit_card_balance.csv')
cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
# Features: Perform aggregations
num_aggregations = {
    'MONTHS_BALANCE': ['min','max', 'mean'],
    'AMT_BALANCE': ['min','max', 'mean','sum'],
    'AMT_CREDIT_LIMIT_ACTUAL': ['min','max', 'mean','sum','var'],
    'AMT_DRAWINGS_ATM_CURRENT': ['min','max', 'mean','sum'],
    'AMT_DRAWINGS_CURRENT': ['min','max', 'mean','sum'],
    'AMT_DRAWINGS_OTHER_CURRENT': ['min','max', 'mean','sum'],
    'AMT_DRAWINGS_POS_CURRENT': ['min','max', 'mean','sum'],
    'AMT_INST_MIN_REGULARITY': ['min','max', 'mean','sum','var'],
    'AMT_PAYMENT_CURRENT':['min','max', 'mean','sum'],
    'AMT_PAYMENT_TOTAL_CURRENT':['min','max', 'mean','sum'],
    'AMT_RECEIVABLE_PRINCIPAL':['min','max', 'mean','sum','var'],
    'AMT_RECIVABLE':['min','max', 'mean','sum','var'],
    'AMT_TOTAL_RECEIVABLE':['min','max', 'mean','sum','var'],
    'CNT_DRAWINGS_ATM_CURRENT':['mean','sum'],
    'CNT_DRAWINGS_CURRENT':['mean','sum'],
    'CNT_DRAWINGS_OTHER_CURRENT':['mean','sum'],
    'CNT_DRAWINGS_POS_CURRENT':['mean','sum'],
    'CNT_INSTALMENT_MATURE_CUM':['mean','sum'],
    'SK_DPD':['max', 'mean', 'sum'],
    'SK_DPD_DEF':['max', 'mean', 'sum']
}
cat_aggregations = {}
for cat in cat_cols:
    cat_aggregations[cat] = ['mean']
# General aggregations
cc_agg = cc.groupby('SK_ID_CURR').agg(dict(num_aggregations,**cat_aggregations))
cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
# Count credit card lines
cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()

#cc_agg['INSTALLMENTS_PER_LOAN'] = cc_agg['CNT_INSTALMENT_MATURE_CUM_SUM'] / cc_agg['CC_COUNT']
del cc
print cc_agg.shape
gc.collect()

all_data = all_data.join(cc_agg, how='left', on='SK_ID_CURR')
print all_data.shape
del cc_agg
gc.collect()
# Out:
# Read data and test
# ('Shapes : ', (307511, 122), (48744, 121))
# ['NAME_CONTRACT_TYPE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE']
# (356255, 255)
# (356255, 260)
# ['STATUS']
# ['CREDIT_ACTIVE', 'CREDIT_CURRENCY', 'CREDIT_TYPE']
# (817395, 13)
# (305811, 67)
# (305811, 100)
# (305811, 135)
# (356255, 394)
# ['NAME_CONTRACT_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT', 'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE', 'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION']
# (338857, 208)
# (338857, 258)
# (338857, 307)
# (356255, 700)
# ['NAME_CONTRACT_STATUS']
# (337252, 24)
# (356255, 724)
# []
# (339587, 29)
# (356255, 753)
# ['NAME_CONTRACT_STATUS']
# (103558, 81)
# (356255, 834)
# 7

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})

drop_col = missing_data[missing_data['Missing Ratio']==100]
missing_data = missing_data[missing_data['Missing Ratio']<100]

all_data.drop(drop_col.index.values,1,inplace=True)

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})

drop_col = missing_data[missing_data['Missing Ratio']==100]
missing_data = missing_data[missing_data['Missing Ratio']<100]

all_data.drop(drop_col.index.values,1,inplace=True)

for i in missing_data.index.values:
    all_data[i] = all_data[i].fillna(-999999999)

all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})

missing_data

all_data[all_data==np.inf]=999999999

# %%
data = all_data[:n_data]
test = all_data[n_data:]
#del avg_buro, avg_prev,avg_pos,avg_cc_bal,avg_inst
del all_data
gc.collect()
print data.shape
print test.shape

exclude_fea = []
exclude_fea.append('SK_ID_CURR') 
exclude_fea
# Out:
# (307511, 819)
# (48744, 819)
# ['SK_ID_CURR']

# %%
folds = KFold(n_splits=5, shuffle=True, random_state=1700)
oof_preds = np.zeros(data.shape[0])
sub_preds = np.zeros(test.shape[0])
feature_importance_df = pd.DataFrame()
feats = [f for f in data.columns if f not in exclude_fea]

# %%
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(data)):
    trn_x, trn_y = data[feats].iloc[trn_idx], y.iloc[trn_idx]
    val_x, val_y = data[feats].iloc[val_idx], y.iloc[val_idx]
    
    clf = LogisticRegression(solver='sag',max_iter=1000,verbose=10,n_jobs=-1,C=10,random_state=1700)

    clf.fit(trn_x, trn_y)
    
    oof_preds[val_idx] = clf.predict_proba(val_x)[:, 1]
    sub_preds += clf.predict_proba(test[feats])[:, 1] / folds.n_splits
    print('Fold %2d Train AUC : %.6f' % (n_fold + 1, roc_auc_score(trn_y, clf.predict_proba(trn_x)[:, 1])))
    print('Fold %2d Test AUC : %.6f' % (n_fold + 1, roc_auc_score(val_y, oof_preds[val_idx])))
    del clf, trn_x, trn_y, val_x, val_y
    gc.collect()
    if n_fold == 0:
        break
    
print('Full AUC score %.6f' % roc_auc_score(y, oof_preds))
# Out:
# max_iter reached after 1447 seconds
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 24.1min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d8b34d054e9b> in <module>()
#       5     clf = LogisticRegression(solver='sag',max_iter=1000,verbose=10,n_jobs=-1,C=10,random_state=1700)
#       6
# ----> 7     clf.fit(trn_x, trn_y)
#       8
#       9     oof_preds[val_idx] = clf.predict_proba(val_x)[:, 1]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1289                       max_squared_sum=max_squared_sum,
#    1290                       sample_weight=sample_weight)
# -> 1291             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1292
#    1293         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python2.7/dist-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# /usr/lib/python2.7/multiprocessing/pool.py in get(self, timeout)
#     559
#     560     def get(self, timeout=None):
# --> 561         self.wait(timeout)
#     562         if not self._ready:
#     563             raise TimeoutError
#
# /usr/lib/python2.7/multiprocessing/pool.py in wait(self, timeout)
#     554         try:
#     555             if not self._ready:
# --> 556                 self._cond.wait(timeout)
#     557         finally:
#     558             self._cond.release()
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     338         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     339             if timeout is None:
# --> 340                 waiter.acquire()
#     341                 if __debug__:
#     342                     self._note("%s.wait(): got it", self)
#
# KeyboardInterrupt:

# %%
def lgbcv(num_leaves, colsample_bytree,subsample,reg_alpha,reg_lambda,min_split_gain,min_child_weight):
    folds = KFold(n_splits=5, shuffle=True, random_state=1700)
    feats = [f for f in data.columns if f not in exclude_fea]
    oof_preds = np.zeros(data.shape[0])
    for n_fold, (trn_idx, val_idx) in enumerate(folds.split(data)):
        trn_x, trn_y = data[feats].iloc[trn_idx], y.iloc[trn_idx]
        val_x, val_y = data[feats].iloc[val_idx], y.iloc[val_idx]

        clf = LGBMClassifier(
        n_estimators=10000,
        learning_rate=0.05,
        num_leaves=int(num_leaves),
        colsample_bytree=max(min(colsample_bytree, 1), 0),
        subsample=max(min(subsample, 1), 0),
        max_depth=8,
        reg_alpha=max(reg_alpha, 0),
        reg_lambda=max(reg_lambda, 0),
        min_split_gain=max(min_split_gain, 0),
        min_child_weight=max(min_child_weight, 0),
        random_state=1700,
        )
        clf.fit(trn_x, trn_y, 
            eval_set= [(trn_x, trn_y), (val_x, val_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100  #30
           )

        oof_preds[val_idx] = clf.predict_proba(val_x, num_iteration=clf.best_iteration_)[:, 1]
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(val_y, oof_preds[val_idx])))
        del clf, trn_x, trn_y, val_x, val_y
        gc.collect()
    full_auc = roc_auc_score(y, oof_preds)
    print('Full AUC score %.6f' % full_auc) 
    return(full_auc)

# %%
lgbBO = BayesianOptimization(
        lgbcv,
        {'num_leaves': (20, 100),
        'colsample_bytree': (0.5, 1.0),
        'subsample':(0.5,1.0),
        'reg_alpha':(0.001,10),
        'reg_lambda':(0.001,10),
        'min_split_gain':(0.0001,10),
        'min_child_weight':(20,120)}
    )

# %%
lgbBO.maximize(init_points=2,n_iter=15)
# Out:
# Initialization
# ----------------------------------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   min_child_weight |   min_split_gain |   num_leaves |   reg_alpha |   reg_lambda |   subsample |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.790898	valid_1's auc: 0.771298
# [200]	training's auc: 0.809141	valid_1's auc: 0.783415
# [300]	training's auc: 0.814748	valid_1's auc: 0.786341
# [400]	training's auc: 0.81748	valid_1's auc: 0.787469
# [500]	training's auc: 0.819464	valid_1's auc: 0.788358
# [600]	training's auc: 0.820843	valid_1's auc: 0.788806
# [700]	training's auc: 0.821864	valid_1's auc: 0.788962
# [800]	training's auc: 0.822801	valid_1's auc: 0.789174
# [900]	training's auc: 0.823705	valid_1's auc: 0.789364
# [1000]	training's auc: 0.824642	valid_1's auc: 0.789726
# [1100]	training's auc: 0.824906	valid_1's auc: 0.789708
# Early stopping, best iteration is:
# [1035]	training's auc: 0.824894	valid_1's auc: 0.789762
# Fold  1 AUC : 0.789762
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.788735	valid_1's auc: 0.775744
# [200]	training's auc: 0.807516	valid_1's auc: 0.78822
# [300]	training's auc: 0.813058	valid_1's auc: 0.791257
# [400]	training's auc: 0.81622	valid_1's auc: 0.792692
# [500]	training's auc: 0.81812	valid_1's auc: 0.793421
# [600]	training's auc: 0.81955	valid_1's auc: 0.793952
# [700]	training's auc: 0.820702	valid_1's auc: 0.794377
# [800]	training's auc: 0.821794	valid_1's auc: 0.794805
# [900]	training's auc: 0.822148	valid_1's auc: 0.794927
# Early stopping, best iteration is:
# [821]	training's auc: 0.822015	valid_1's auc: 0.794964
# Fold  2 AUC : 0.794964
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.789664	valid_1's auc: 0.773526
# [200]	training's auc: 0.808861	valid_1's auc: 0.78464
# [300]	training's auc: 0.814642	valid_1's auc: 0.786739
# [400]	training's auc: 0.817674	valid_1's auc: 0.787921
# [500]	training's auc: 0.819534	valid_1's auc: 0.788643
# [600]	training's auc: 0.821058	valid_1's auc: 0.788979
# [700]	training's auc: 0.822346	valid_1's auc: 0.789345
# [800]	training's auc: 0.823362	valid_1's auc: 0.789464
# [900]	training's auc: 0.824235	valid_1's auc: 0.789648
# [1000]	training's auc: 0.825007	valid_1's auc: 0.789722
# Early stopping, best iteration is:
# [978]	training's auc: 0.824894	valid_1's auc: 0.78977
# Fold  3 AUC : 0.789770
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.789162	valid_1's auc: 0.772985
# [200]	training's auc: 0.809166	valid_1's auc: 0.78539
# [300]	training's auc: 0.814983	valid_1's auc: 0.78837
# [400]	training's auc: 0.817975	valid_1's auc: 0.789608
# [500]	training's auc: 0.819953	valid_1's auc: 0.790299
# [600]	training's auc: 0.821482	valid_1's auc: 0.790765
# [700]	training's auc: 0.822696	valid_1's auc: 0.791178
# [800]	training's auc: 0.823565	valid_1's auc: 0.791356
# [900]	training's auc: 0.824535	valid_1's auc: 0.791552
# [1000]	training's auc: 0.825267	valid_1's auc: 0.791594
# [1100]	training's auc: 0.825975	valid_1's auc: 0.791594
# [1200]	training's auc: 0.826704	valid_1's auc: 0.791723
# Early stopping, best iteration is:
# [1156]	training's auc: 0.826366	valid_1's auc: 0.791753
# Fold  4 AUC : 0.791702
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.790434	valid_1's auc: 0.766892
# [200]	training's auc: 0.808982	valid_1's auc: 0.779247
# [300]	training's auc: 0.814957	valid_1's auc: 0.782382
# [400]	training's auc: 0.817917	valid_1's auc: 0.7836
# [500]	training's auc: 0.819856	valid_1's auc: 0.784375
# [600]	training's auc: 0.821359	valid_1's auc: 0.784701
# [700]	training's auc: 0.822566	valid_1's auc: 0.784951
# [800]	training's auc: 0.823468	valid_1's auc: 0.784999
# [900]	training's auc: 0.824395	valid_1's auc: 0.785156
# Early stopping, best iteration is:
# [897]	training's auc: 0.824356	valid_1's auc: 0.785172
# Fold  5 AUC : 0.785160
# Full AUC score 0.790253
#     1 | 08m30s |    0.79025 |             0.7635 |           109.3985 |           5.2167 |      97.9930 |      9.0144 |       0.1190 |      0.5248 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.793467	valid_1's auc: 0.770438
# [200]	training's auc: 0.820902	valid_1's auc: 0.78404
# [300]	training's auc: 0.837263	valid_1's auc: 0.788186
# [400]	training's auc: 0.851345	valid_1's auc: 0.79016
# [500]	training's auc: 0.863841	valid_1's auc: 0.791039
# [600]	training's auc: 0.874813	valid_1's auc: 0.791255
# [700]	training's auc: 0.885004	valid_1's auc: 0.79152
# [800]	training's auc: 0.894323	valid_1's auc: 0.791671
# [900]	training's auc: 0.90251	valid_1's auc: 0.791395
# Early stopping, best iteration is:
# [861]	training's auc: 0.899322	valid_1's auc: 0.791747
# Fold  1 AUC : 0.791747
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.791839	valid_1's auc: 0.776308
# [200]	training's auc: 0.82018	valid_1's auc: 0.789878
# [300]	training's auc: 0.836628	valid_1's auc: 0.794056
# [400]	training's auc: 0.850343	valid_1's auc: 0.795426
# [500]	training's auc: 0.861978	valid_1's auc: 0.795961
# [600]	training's auc: 0.872903	valid_1's auc: 0.796387
# Early stopping, best iteration is:
# [590]	training's auc: 0.87183	valid_1's auc: 0.79644
# Fold  2 AUC : 0.796440
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.792971	valid_1's auc: 0.773789
# [200]	training's auc: 0.820791	valid_1's auc: 0.786193
# [300]	training's auc: 0.837295	valid_1's auc: 0.789594
# [400]	training's auc: 0.851252	valid_1's auc: 0.790897
# [500]	training's auc: 0.862818	valid_1's auc: 0.791502
# [600]	training's auc: 0.873746	valid_1's auc: 0.791889
# [700]	training's auc: 0.883532	valid_1's auc: 0.792106
# Early stopping, best iteration is:
# [671]	training's auc: 0.880812	valid_1's auc: 0.792114
# Fold  3 AUC : 0.792114
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.792894	valid_1's auc: 0.774242
# [200]	training's auc: 0.820861	valid_1's auc: 0.787083
# [300]	training's auc: 0.837566	valid_1's auc: 0.790957
# [400]	training's auc: 0.8511	valid_1's auc: 0.792617
# [500]	training's auc: 0.862842	valid_1's auc: 0.79321
# Early stopping, best iteration is:
# [497]	training's auc: 0.862533	valid_1's auc: 0.793253
# Fold  4 AUC : 0.793253
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.793887	valid_1's auc: 0.767311
# [200]	training's auc: 0.821619	valid_1's auc: 0.781567
# [300]	training's auc: 0.837672	valid_1's auc: 0.786103
# [400]	training's auc: 0.8509	valid_1's auc: 0.78735
# [500]	training's auc: 0.862727	valid_1's auc: 0.788234
# [600]	training's auc: 0.873648	valid_1's auc: 0.788598
# Early stopping, best iteration is:
# [582]	training's auc: 0.871546	valid_1's auc: 0.788638
# Fold  5 AUC : 0.788638
# Full AUC score 0.792409
#     2 | 12m14s |    0.79241 |             0.8185 |            76.7848 |           0.2611 |      35.8914 |      7.8412 |       7.5831 |      0.8393 |
# Bayesian Optimization
# ----------------------------------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   min_child_weight |   min_split_gain |   num_leaves |   reg_alpha |   reg_lambda |   subsample |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.791981	valid_1's auc: 0.770544
# [200]	training's auc: 0.805935	valid_1's auc: 0.782091
# [300]	training's auc: 0.808505	valid_1's auc: 0.784505
# [400]	training's auc: 0.809447	valid_1's auc: 0.785327
# Early stopping, best iteration is:
# [383]	training's auc: 0.809447	valid_1's auc: 0.785327
# Fold  1 AUC : 0.785327
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.789649	valid_1's auc: 0.775599
# [200]	training's auc: 0.804366	valid_1's auc: 0.786796
# [300]	training's auc: 0.80687	valid_1's auc: 0.788755
# [400]	training's auc: 0.807875	valid_1's auc: 0.789754
# Early stopping, best iteration is:
# [387]	training's auc: 0.807875	valid_1's auc: 0.789754
# Fold  2 AUC : 0.789754
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.791622	valid_1's auc: 0.77343
# [200]	training's auc: 0.80586	valid_1's auc: 0.783218
# [300]	training's auc: 0.808545	valid_1's auc: 0.785186
# [400]	training's auc: 0.809688	valid_1's auc: 0.786002
# [500]	training's auc: 0.809912	valid_1's auc: 0.786153
# Early stopping, best iteration is:
# [442]	training's auc: 0.809904	valid_1's auc: 0.786159
# Fold  3 AUC : 0.786153
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.791617	valid_1's auc: 0.774153
# [200]	training's auc: 0.806038	valid_1's auc: 0.784385
# [300]	training's auc: 0.808722	valid_1's auc: 0.786473
# [400]	training's auc: 0.809237	valid_1's auc: 0.786783
# Early stopping, best iteration is:
# [335]	training's auc: 0.809194	valid_1's auc: 0.786799
# Fold  4 AUC : 0.786799
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.79254	valid_1's auc: 0.768329
# [200]	training's auc: 0.806219	valid_1's auc: 0.778956
# [300]	training's auc: 0.808942	valid_1's auc: 0.781461
# [400]	training's auc: 0.809635	valid_1's auc: 0.782028
# Early stopping, best iteration is:
# [365]	training's auc: 0.809635	valid_1's auc: 0.782028
# Fold  5 AUC : 0.782028
# Full AUC score 0.785995
#     3 | 04m47s |    0.78600 |             0.5610 |            20.1188 |           9.9236 |      99.8846 |      7.2057 |       7.2912 |      0.6642 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782803	valid_1's auc: 0.767027
# [200]	training's auc: 0.804514	valid_1's auc: 0.782805
# [300]	training's auc: 0.808352	valid_1's auc: 0.785551
# [400]	training's auc: 0.809699	valid_1's auc: 0.786533
# [500]	training's auc: 0.809902	valid_1's auc: 0.7867
# Early stopping, best iteration is:
# [416]	training's auc: 0.809902	valid_1's auc: 0.7867
# Fold  1 AUC : 0.786700
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.7809	valid_1's auc: 0.771811
# [200]	training's auc: 0.802821	valid_1's auc: 0.787492
# [300]	training's auc: 0.806935	valid_1's auc: 0.790184
# [400]	training's auc: 0.80806	valid_1's auc: 0.791045
# [500]	training's auc: 0.808355	valid_1's auc: 0.791224
# Early stopping, best iteration is:
# [431]	training's auc: 0.808355	valid_1's auc: 0.791215
# Fold  2 AUC : 0.791224
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.781952	valid_1's auc: 0.770076
# [200]	training's auc: 0.804415	valid_1's auc: 0.783815
# [300]	training's auc: 0.808793	valid_1's auc: 0.786242
# [400]	training's auc: 0.810167	valid_1's auc: 0.786978
# [500]	training's auc: 0.810622	valid_1's auc: 0.787199
# Early stopping, best iteration is:
# [481]	training's auc: 0.810611	valid_1's auc: 0.787203
# Fold  3 AUC : 0.787199
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.781841	valid_1's auc: 0.770543
# [200]	training's auc: 0.803944	valid_1's auc: 0.784809
# [300]	training's auc: 0.808195	valid_1's auc: 0.787336
# [400]	training's auc: 0.809739	valid_1's auc: 0.788225
# [500]	training's auc: 0.810245	valid_1's auc: 0.788539
# Early stopping, best iteration is:
# [464]	training's auc: 0.810245	valid_1's auc: 0.788539
# Fold  4 AUC : 0.788539
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.783743	valid_1's auc: 0.764135
# [200]	training's auc: 0.805165	valid_1's auc: 0.778441
# [300]	training's auc: 0.809241	valid_1's auc: 0.78159
# [400]	training's auc: 0.810544	valid_1's auc: 0.782447
# Early stopping, best iteration is:
# [390]	training's auc: 0.810544	valid_1's auc: 0.782447
# Fold  5 AUC : 0.782447
# Full AUC score 0.787200
#     4 | 05m25s |    0.78720 |             0.5973 |           119.1125 |           9.5920 |      20.3714 |      0.9413 |       8.5023 |      0.7582 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782295	valid_1's auc: 0.767073
# [200]	training's auc: 0.806058	valid_1's auc: 0.783719
# [300]	training's auc: 0.819267	valid_1's auc: 0.788248
# [400]	training's auc: 0.829762	valid_1's auc: 0.790387
# [500]	training's auc: 0.83899	valid_1's auc: 0.791344
# [600]	training's auc: 0.847275	valid_1's auc: 0.791839
# [700]	training's auc: 0.85468	valid_1's auc: 0.792203
# [800]	training's auc: 0.862088	valid_1's auc: 0.791953
# Early stopping, best iteration is:
# [756]	training's auc: 0.858977	valid_1's auc: 0.792342
# Fold  1 AUC : 0.792342
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.780752	valid_1's auc: 0.772493
# [200]	training's auc: 0.804748	valid_1's auc: 0.788435
# [300]	training's auc: 0.818116	valid_1's auc: 0.793024
# [400]	training's auc: 0.828673	valid_1's auc: 0.794635
# [500]	training's auc: 0.838239	valid_1's auc: 0.795701
# [600]	training's auc: 0.846692	valid_1's auc: 0.796239
# [700]	training's auc: 0.854207	valid_1's auc: 0.796865
# [800]	training's auc: 0.861594	valid_1's auc: 0.797215
# [900]	training's auc: 0.868509	valid_1's auc: 0.797476
# [1000]	training's auc: 0.874786	valid_1's auc: 0.797696
# Early stopping, best iteration is:
# [977]	training's auc: 0.873373	valid_1's auc: 0.797828
# Fold  2 AUC : 0.797828
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782076	valid_1's auc: 0.771047
# [200]	training's auc: 0.806163	valid_1's auc: 0.784606
# [300]	training's auc: 0.819755	valid_1's auc: 0.788849
# [400]	training's auc: 0.83041	valid_1's auc: 0.790583
# [500]	training's auc: 0.839586	valid_1's auc: 0.791111
# [600]	training's auc: 0.848299	valid_1's auc: 0.791501
# [700]	training's auc: 0.855919	valid_1's auc: 0.791684
# Early stopping, best iteration is:
# [699]	training's auc: 0.855862	valid_1's auc: 0.791692
# Fold  3 AUC : 0.791692
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782091	valid_1's auc: 0.771186
# [200]	training's auc: 0.80619	valid_1's auc: 0.785548
# [300]	training's auc: 0.819373	valid_1's auc: 0.789638
# [400]	training's auc: 0.830115	valid_1's auc: 0.791767
# [500]	training's auc: 0.839205	valid_1's auc: 0.792308
# [600]	training's auc: 0.847851	valid_1's auc: 0.793101
# [700]	training's auc: 0.855721	valid_1's auc: 0.793358
# [800]	training's auc: 0.862947	valid_1's auc: 0.793418
# [900]	training's auc: 0.869776	valid_1's auc: 0.793534
# [1000]	training's auc: 0.876093	valid_1's auc: 0.793391
# Early stopping, best iteration is:
# [957]	training's auc: 0.873415	valid_1's auc: 0.793652
# Fold  4 AUC : 0.793652
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782796	valid_1's auc: 0.763508
# [200]	training's auc: 0.806631	valid_1's auc: 0.779244
# [300]	training's auc: 0.819656	valid_1's auc: 0.783845
# [400]	training's auc: 0.830311	valid_1's auc: 0.785625
# [500]	training's auc: 0.839572	valid_1's auc: 0.786749
# [600]	training's auc: 0.848209	valid_1's auc: 0.787359
# [700]	training's auc: 0.856124	valid_1's auc: 0.787436
# Early stopping, best iteration is:
# [637]	training's auc: 0.851203	valid_1's auc: 0.787633
# Fold  5 AUC : 0.787633
# Full AUC score 0.792628
#     5 | 10m21s |    0.79263 |             0.8281 |            25.7119 |           0.6667 |      20.5985 |      8.0709 |       0.0376 |      0.6215 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.817614	valid_1's auc: 0.775251
# [200]	training's auc: 0.843985	valid_1's auc: 0.786559
# [300]	training's auc: 0.858604	valid_1's auc: 0.789525
# [400]	training's auc: 0.870529	valid_1's auc: 0.790732
# [500]	training's auc: 0.881418	valid_1's auc: 0.791368
# [600]	training's auc: 0.89101	valid_1's auc: 0.791484
# Early stopping, best iteration is:
# [572]	training's auc: 0.88798	valid_1's auc: 0.791709
# Fold  1 AUC : 0.791709
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.816137	valid_1's auc: 0.779889
# [200]	training's auc: 0.842256	valid_1's auc: 0.791302
# [300]	training's auc: 0.856747	valid_1's auc: 0.793915
# [400]	training's auc: 0.868664	valid_1's auc: 0.795783
# [500]	training's auc: 0.879321	valid_1's auc: 0.796223
# [600]	training's auc: 0.889063	valid_1's auc: 0.796255
# [700]	training's auc: 0.897999	valid_1's auc: 0.79581
# Early stopping, best iteration is:
# [610]	training's auc: 0.889925	valid_1's auc: 0.79633
# Fold  2 AUC : 0.796330
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.816266	valid_1's auc: 0.777684
# [200]	training's auc: 0.842446	valid_1's auc: 0.787825
# [300]	training's auc: 0.857172	valid_1's auc: 0.789998
# [400]	training's auc: 0.869414	valid_1's auc: 0.791082
# [500]	training's auc: 0.880152	valid_1's auc: 0.79132
# [600]	training's auc: 0.88969	valid_1's auc: 0.791373
# Early stopping, best iteration is:
# [589]	training's auc: 0.888937	valid_1's auc: 0.791433
# Fold  3 AUC : 0.791433
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.815968	valid_1's auc: 0.777774
# [200]	training's auc: 0.842581	valid_1's auc: 0.788499
# [300]	training's auc: 0.85693	valid_1's auc: 0.791017
# [400]	training's auc: 0.869361	valid_1's auc: 0.791582
# [500]	training's auc: 0.879847	valid_1's auc: 0.792228
# [600]	training's auc: 0.890217	valid_1's auc: 0.791787
# Early stopping, best iteration is:
# [511]	training's auc: 0.880914	valid_1's auc: 0.792241
# Fold  4 AUC : 0.792241
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.816387	valid_1's auc: 0.77231
# [200]	training's auc: 0.842067	valid_1's auc: 0.783723
# [300]	training's auc: 0.855858	valid_1's auc: 0.787027
# [400]	training's auc: 0.868232	valid_1's auc: 0.788219
# [500]	training's auc: 0.878923	valid_1's auc: 0.788811
# [600]	training's auc: 0.888058	valid_1's auc: 0.788768
# [700]	training's auc: 0.896879	valid_1's auc: 0.789068
# Early stopping, best iteration is:
# [696]	training's auc: 0.8966	valid_1's auc: 0.789168
# Fold  5 AUC : 0.789168
# Full AUC score 0.792144
#     6 | 12m28s |    0.79214 |             0.9277 |           100.7248 |           0.1718 |      88.6431 |      0.0346 |       0.2091 |      0.8788 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.784051	valid_1's auc: 0.766731
# [200]	training's auc: 0.808281	valid_1's auc: 0.782728
# [300]	training's auc: 0.821086	valid_1's auc: 0.787206
# [400]	training's auc: 0.831388	valid_1's auc: 0.789201
# [500]	training's auc: 0.840522	valid_1's auc: 0.790278
# [600]	training's auc: 0.848634	valid_1's auc: 0.790941
# [700]	training's auc: 0.856096	valid_1's auc: 0.791312
# [800]	training's auc: 0.863042	valid_1's auc: 0.791789
# [900]	training's auc: 0.869455	valid_1's auc: 0.791689
# Early stopping, best iteration is:
# [806]	training's auc: 0.863379	valid_1's auc: 0.791852
# Fold  1 AUC : 0.791852
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782144	valid_1's auc: 0.772053
# [200]	training's auc: 0.806804	valid_1's auc: 0.787985
# [300]	training's auc: 0.819673	valid_1's auc: 0.792863
# [400]	training's auc: 0.830052	valid_1's auc: 0.794657
# [500]	training's auc: 0.838602	valid_1's auc: 0.795699
# [600]	training's auc: 0.846768	valid_1's auc: 0.796432
# [700]	training's auc: 0.854291	valid_1's auc: 0.796522
# [800]	training's auc: 0.861314	valid_1's auc: 0.796604
# [900]	training's auc: 0.867888	valid_1's auc: 0.796638
# Early stopping, best iteration is:
# [862]	training's auc: 0.865486	valid_1's auc: 0.796807
# Fold  2 AUC : 0.796807
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.783141	valid_1's auc: 0.770255
# [200]	training's auc: 0.808032	valid_1's auc: 0.784378
# [300]	training's auc: 0.820967	valid_1's auc: 0.788183
# [400]	training's auc: 0.831245	valid_1's auc: 0.790082
# [500]	training's auc: 0.840118	valid_1's auc: 0.790941
# [600]	training's auc: 0.848298	valid_1's auc: 0.791401
# [700]	training's auc: 0.855632	valid_1's auc: 0.791577
# [800]	training's auc: 0.862585	valid_1's auc: 0.791601
# Early stopping, best iteration is:
# [723]	training's auc: 0.857199	valid_1's auc: 0.791737
# Fold  3 AUC : 0.791737
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.783306	valid_1's auc: 0.770817
# [200]	training's auc: 0.807883	valid_1's auc: 0.785543
# [300]	training's auc: 0.820981	valid_1's auc: 0.789764
# [400]	training's auc: 0.831305	valid_1's auc: 0.791356
# [500]	training's auc: 0.840422	valid_1's auc: 0.792207
# [600]	training's auc: 0.848598	valid_1's auc: 0.79276
# [700]	training's auc: 0.856007	valid_1's auc: 0.793205
# [800]	training's auc: 0.862975	valid_1's auc: 0.793668
# [900]	training's auc: 0.869483	valid_1's auc: 0.79384
# [1000]	training's auc: 0.87566	valid_1's auc: 0.793371
# Early stopping, best iteration is:
# [906]	training's auc: 0.869925	valid_1's auc: 0.793876
# Fold  4 AUC : 0.793876
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.785176	valid_1's auc: 0.76419
# [200]	training's auc: 0.80897	valid_1's auc: 0.779052
# [300]	training's auc: 0.821859	valid_1's auc: 0.783923
# [400]	training's auc: 0.832096	valid_1's auc: 0.786186
# [500]	training's auc: 0.841008	valid_1's auc: 0.787207
# [600]	training's auc: 0.849096	valid_1's auc: 0.787873
# [700]	training's auc: 0.856565	valid_1's auc: 0.78815
# [800]	training's auc: 0.863632	valid_1's auc: 0.788498
# [900]	training's auc: 0.870216	valid_1's auc: 0.788216
# Early stopping, best iteration is:
# [801]	training's auc: 0.863697	valid_1's auc: 0.788505
# Fold  5 AUC : 0.788505
# Full AUC score 0.792539
#     7 | 13m18s |    0.79254 |             0.6163 |           113.5434 |           0.0951 |      22.9561 |      8.9642 |       1.1482 |      0.9040 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.795191	valid_1's auc: 0.771858
# [200]	training's auc: 0.820563	valid_1's auc: 0.784344
# [300]	training's auc: 0.835529	valid_1's auc: 0.787986
# [400]	training's auc: 0.849154	valid_1's auc: 0.789303
# [500]	training's auc: 0.860967	valid_1's auc: 0.789812
# [600]	training's auc: 0.871722	valid_1's auc: 0.790135
# [700]	training's auc: 0.881865	valid_1's auc: 0.789729
# Early stopping, best iteration is:
# [610]	training's auc: 0.872799	valid_1's auc: 0.790187
# Fold  1 AUC : 0.790187
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.793016	valid_1's auc: 0.776638
# [200]	training's auc: 0.818862	valid_1's auc: 0.788978
# [300]	training's auc: 0.834139	valid_1's auc: 0.792557
# [400]	training's auc: 0.847722	valid_1's auc: 0.79407
# [500]	training's auc: 0.859811	valid_1's auc: 0.794797
# [600]	training's auc: 0.870433	valid_1's auc: 0.795333
# [700]	training's auc: 0.880028	valid_1's auc: 0.795697
# [800]	training's auc: 0.889116	valid_1's auc: 0.795655
# Early stopping, best iteration is:
# [768]	training's auc: 0.886351	valid_1's auc: 0.795854
# Fold  2 AUC : 0.795854
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.794239	valid_1's auc: 0.773482
# [200]	training's auc: 0.820077	valid_1's auc: 0.784843
# [300]	training's auc: 0.835759	valid_1's auc: 0.788061
# [400]	training's auc: 0.848745	valid_1's auc: 0.789277
# [500]	training's auc: 0.860148	valid_1's auc: 0.790046
# [600]	training's auc: 0.871072	valid_1's auc: 0.790308
# Early stopping, best iteration is:
# [565]	training's auc: 0.867408	valid_1's auc: 0.790564
# Fold  3 AUC : 0.790564
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.79438	valid_1's auc: 0.774192
# [200]	training's auc: 0.820087	valid_1's auc: 0.786423
# [300]	training's auc: 0.835572	valid_1's auc: 0.78982
# [400]	training's auc: 0.848424	valid_1's auc: 0.790716
# [500]	training's auc: 0.860792	valid_1's auc: 0.790891
# Early stopping, best iteration is:
# [430]	training's auc: 0.852202	valid_1's auc: 0.791037
# Fold  4 AUC : 0.791037
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.794675	valid_1's auc: 0.768436
# [200]	training's auc: 0.820393	valid_1's auc: 0.781683
# [300]	training's auc: 0.835573	valid_1's auc: 0.784904
# [400]	training's auc: 0.848666	valid_1's auc: 0.786059
# [500]	training's auc: 0.860076	valid_1's auc: 0.786515
# [600]	training's auc: 0.871121	valid_1's auc: 0.78646
# Early stopping, best iteration is:
# [514]	training's auc: 0.861623	valid_1's auc: 0.786573
# Fold  5 AUC : 0.786573
# Full AUC score 0.790822
#     8 | 11m09s |    0.79082 |             0.8102 |           119.5420 |           0.2182 |      96.2088 |      8.9841 |       9.8512 |      0.6194 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.800262	valid_1's auc: 0.771963
# [200]	training's auc: 0.82821	valid_1's auc: 0.785056
# [300]	training's auc: 0.845556	valid_1's auc: 0.788722
# [400]	training's auc: 0.860672	valid_1's auc: 0.790755
# [500]	training's auc: 0.873508	valid_1's auc: 0.791733
# [600]	training's auc: 0.885496	valid_1's auc: 0.791851
# Early stopping, best iteration is:
# [548]	training's auc: 0.879293	valid_1's auc: 0.791942
# Fold  1 AUC : 0.791942
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.798403	valid_1's auc: 0.777946
# [200]	training's auc: 0.827326	valid_1's auc: 0.790531
# [300]	training's auc: 0.844646	valid_1's auc: 0.793879
# [400]	training's auc: 0.858799	valid_1's auc: 0.795587
# [500]	training's auc: 0.871574	valid_1's auc: 0.795953
# [600]	training's auc: 0.883237	valid_1's auc: 0.796335
# [700]	training's auc: 0.894244	valid_1's auc: 0.796303
# Early stopping, best iteration is:
# [608]	training's auc: 0.884208	valid_1's auc: 0.796433
# Fold  2 AUC : 0.796433
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.799299	valid_1's auc: 0.77556
# [200]	training's auc: 0.827951	valid_1's auc: 0.78692
# [300]	training's auc: 0.845146	valid_1's auc: 0.789704
# [400]	training's auc: 0.859947	valid_1's auc: 0.791009
# [500]	training's auc: 0.873009	valid_1's auc: 0.791504
# [600]	training's auc: 0.884851	valid_1's auc: 0.791774
# [700]	training's auc: 0.895795	valid_1's auc: 0.791494
# Early stopping, best iteration is:
# [647]	training's auc: 0.890101	valid_1's auc: 0.791983
# Fold  3 AUC : 0.791983
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.799133	valid_1's auc: 0.775419
# [200]	training's auc: 0.827794	valid_1's auc: 0.78707
# [300]	training's auc: 0.845192	valid_1's auc: 0.790315
# [400]	training's auc: 0.859402	valid_1's auc: 0.792085
# [500]	training's auc: 0.872486	valid_1's auc: 0.792502
# Early stopping, best iteration is:
# [492]	training's auc: 0.871539	valid_1's auc: 0.79258
# Fold  4 AUC : 0.792580
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.800495	valid_1's auc: 0.770212
# [200]	training's auc: 0.828275	valid_1's auc: 0.782925
# [300]	training's auc: 0.844274	valid_1's auc: 0.786328
# [400]	training's auc: 0.859129	valid_1's auc: 0.787579
# [500]	training's auc: 0.872208	valid_1's auc: 0.787899
# [600]	training's auc: 0.883714	valid_1's auc: 0.788162
# Early stopping, best iteration is:
# [589]	training's auc: 0.882454	valid_1's auc: 0.7883
# Fold  5 AUC : 0.788300
# Full AUC score 0.792221
#     9 | 12m43s |    0.79222 |             0.5115 |            64.5362 |           0.1620 |      45.7948 |      9.6616 |       0.5890 |      0.9707 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.783999	valid_1's auc: 0.767434
# [200]	training's auc: 0.809494	valid_1's auc: 0.78355
# [300]	training's auc: 0.823483	valid_1's auc: 0.787583
# [400]	training's auc: 0.835136	valid_1's auc: 0.789416
# [500]	training's auc: 0.845156	valid_1's auc: 0.790706
# [600]	training's auc: 0.854377	valid_1's auc: 0.790868
# [700]	training's auc: 0.86246	valid_1's auc: 0.791387
# [800]	training's auc: 0.870536	valid_1's auc: 0.791699
# [900]	training's auc: 0.878024	valid_1's auc: 0.791383
# Early stopping, best iteration is:
# [835]	training's auc: 0.873102	valid_1's auc: 0.791783
# Fold  1 AUC : 0.791783
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782103	valid_1's auc: 0.772775
# [200]	training's auc: 0.808309	valid_1's auc: 0.788826
# [300]	training's auc: 0.822552	valid_1's auc: 0.792865
# [400]	training's auc: 0.834193	valid_1's auc: 0.794745
# [500]	training's auc: 0.844328	valid_1's auc: 0.795723
# [600]	training's auc: 0.853218	valid_1's auc: 0.796251
# [700]	training's auc: 0.86121	valid_1's auc: 0.796519
# [800]	training's auc: 0.869256	valid_1's auc: 0.796661
# Early stopping, best iteration is:
# [796]	training's auc: 0.868949	valid_1's auc: 0.796752
# Fold  2 AUC : 0.796752
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.783964	valid_1's auc: 0.770834
# [200]	training's auc: 0.809437	valid_1's auc: 0.784642
# [300]	training's auc: 0.823779	valid_1's auc: 0.788241
# [400]	training's auc: 0.835508	valid_1's auc: 0.789534
# [500]	training's auc: 0.845369	valid_1's auc: 0.790405
# [600]	training's auc: 0.854754	valid_1's auc: 0.790911
# Early stopping, best iteration is:
# [599]	training's auc: 0.854633	valid_1's auc: 0.790945
# Fold  3 AUC : 0.790945
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.783351	valid_1's auc: 0.771677
# [200]	training's auc: 0.809226	valid_1's auc: 0.785469
# [300]	training's auc: 0.82355	valid_1's auc: 0.788947
# [400]	training's auc: 0.835211	valid_1's auc: 0.790292
# [500]	training's auc: 0.845068	valid_1's auc: 0.791046
# [600]	training's auc: 0.854011	valid_1's auc: 0.791446
# [700]	training's auc: 0.86255	valid_1's auc: 0.791557
# [800]	training's auc: 0.870383	valid_1's auc: 0.791301
# Early stopping, best iteration is:
# [716]	training's auc: 0.86383	valid_1's auc: 0.79175
# Fold  4 AUC : 0.791750
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.785582	valid_1's auc: 0.765012
# [200]	training's auc: 0.810428	valid_1's auc: 0.780785
# [300]	training's auc: 0.824534	valid_1's auc: 0.784817
# [400]	training's auc: 0.836104	valid_1's auc: 0.786499
# [500]	training's auc: 0.845985	valid_1's auc: 0.787369
# [600]	training's auc: 0.855208	valid_1's auc: 0.787864
# [700]	training's auc: 0.863853	valid_1's auc: 0.788184
# [800]	training's auc: 0.87137	valid_1's auc: 0.787978
# Early stopping, best iteration is:
# [701]	training's auc: 0.863919	valid_1's auc: 0.788212
# Fold  5 AUC : 0.788212
# Full AUC score 0.791873
#    10 | 10m25s |    0.79187 |             0.9496 |            57.4442 |           0.0323 |      21.7735 |      0.9982 |       1.3918 |      0.6600 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.78316	valid_1's auc: 0.767311
# [200]	training's auc: 0.80668	valid_1's auc: 0.783239
# [300]	training's auc: 0.819464	valid_1's auc: 0.787889
# [400]	training's auc: 0.829405	valid_1's auc: 0.78996
# [500]	training's auc: 0.837909	valid_1's auc: 0.79083
# [600]	training's auc: 0.845491	valid_1's auc: 0.791651
# [700]	training's auc: 0.852444	valid_1's auc: 0.791761
# [800]	training's auc: 0.859114	valid_1's auc: 0.792046
# [900]	training's auc: 0.865175	valid_1's auc: 0.792285
# [1000]	training's auc: 0.870805	valid_1's auc: 0.792129
# Early stopping, best iteration is:
# [901]	training's auc: 0.865211	valid_1's auc: 0.792288
# Fold  1 AUC : 0.792288
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.781556	valid_1's auc: 0.771537
# [200]	training's auc: 0.805787	valid_1's auc: 0.787134
# [300]	training's auc: 0.81836	valid_1's auc: 0.792213
# [400]	training's auc: 0.828304	valid_1's auc: 0.793748
# [500]	training's auc: 0.836913	valid_1's auc: 0.794651
# [600]	training's auc: 0.844575	valid_1's auc: 0.795388
# [700]	training's auc: 0.851415	valid_1's auc: 0.795905
# [800]	training's auc: 0.857969	valid_1's auc: 0.796091
# [900]	training's auc: 0.863948	valid_1's auc: 0.796391
# [1000]	training's auc: 0.869414	valid_1's auc: 0.796367
# Early stopping, best iteration is:
# [911]	training's auc: 0.864518	valid_1's auc: 0.796439
# Fold  2 AUC : 0.796439
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782475	valid_1's auc: 0.770641
# [200]	training's auc: 0.806729	valid_1's auc: 0.78405
# [300]	training's auc: 0.819457	valid_1's auc: 0.788589
# [400]	training's auc: 0.829377	valid_1's auc: 0.79024
# [500]	training's auc: 0.838022	valid_1's auc: 0.791246
# [600]	training's auc: 0.845753	valid_1's auc: 0.791545
# [700]	training's auc: 0.852751	valid_1's auc: 0.791973
# [800]	training's auc: 0.859023	valid_1's auc: 0.792352
# [900]	training's auc: 0.864854	valid_1's auc: 0.792447
# [1000]	training's auc: 0.870541	valid_1's auc: 0.792332
# Early stopping, best iteration is:
# [957]	training's auc: 0.868189	valid_1's auc: 0.792493
# Fold  3 AUC : 0.792493
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782288	valid_1's auc: 0.770343
# [200]	training's auc: 0.806705	valid_1's auc: 0.785065
# [300]	training's auc: 0.819436	valid_1's auc: 0.789643
# [400]	training's auc: 0.829244	valid_1's auc: 0.791402
# [500]	training's auc: 0.837522	valid_1's auc: 0.792132
# [600]	training's auc: 0.845067	valid_1's auc: 0.792764
# [700]	training's auc: 0.852202	valid_1's auc: 0.793399
# [800]	training's auc: 0.858625	valid_1's auc: 0.793588
# [900]	training's auc: 0.864715	valid_1's auc: 0.793669
# Early stopping, best iteration is:
# [831]	training's auc: 0.860524	valid_1's auc: 0.793738
# Fold  4 AUC : 0.793738
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.784168	valid_1's auc: 0.765619
# [200]	training's auc: 0.807559	valid_1's auc: 0.780592
# [300]	training's auc: 0.820025	valid_1's auc: 0.785538
# [400]	training's auc: 0.830176	valid_1's auc: 0.788019
# [500]	training's auc: 0.838719	valid_1's auc: 0.789129
# [600]	training's auc: 0.846344	valid_1's auc: 0.789795
# [700]	training's auc: 0.853291	valid_1's auc: 0.790337
# [800]	training's auc: 0.859879	valid_1's auc: 0.790187
# Early stopping, best iteration is:
# [741]	training's auc: 0.856054	valid_1's auc: 0.79043
# Fold  5 AUC : 0.790430
# Full AUC score 0.793068
#    11 | 13m53s |    0.79307 |             0.5802 |            20.3369 |           0.7650 |      21.1524 |      9.7570 |       8.7767 |      0.9370 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.797295	valid_1's auc: 0.772626
# [200]	training's auc: 0.820703	valid_1's auc: 0.784127
# [300]	training's auc: 0.835563	valid_1's auc: 0.787283
# [400]	training's auc: 0.848135	valid_1's auc: 0.788682
# [500]	training's auc: 0.859781	valid_1's auc: 0.789366
# [600]	training's auc: 0.869952	valid_1's auc: 0.789574
# Early stopping, best iteration is:
# [570]	training's auc: 0.866746	valid_1's auc: 0.78993
# Fold  1 AUC : 0.789930
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.795354	valid_1's auc: 0.777016
# [200]	training's auc: 0.819455	valid_1's auc: 0.788959
# [300]	training's auc: 0.834266	valid_1's auc: 0.792864
# [400]	training's auc: 0.846811	valid_1's auc: 0.794628
# [500]	training's auc: 0.858278	valid_1's auc: 0.795326
# [600]	training's auc: 0.868726	valid_1's auc: 0.795454
# Early stopping, best iteration is:
# [525]	training's auc: 0.861058	valid_1's auc: 0.795617
# Fold  2 AUC : 0.795617
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.796977	valid_1's auc: 0.775554
# [200]	training's auc: 0.820818	valid_1's auc: 0.785917
# [300]	training's auc: 0.835684	valid_1's auc: 0.788523
# [400]	training's auc: 0.847878	valid_1's auc: 0.789927
# [500]	training's auc: 0.858849	valid_1's auc: 0.790164
# Early stopping, best iteration is:
# [447]	training's auc: 0.853243	valid_1's auc: 0.79024
# Fold  3 AUC : 0.790240
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.796586	valid_1's auc: 0.775988
# [200]	training's auc: 0.820597	valid_1's auc: 0.786266
# [300]	training's auc: 0.835734	valid_1's auc: 0.789297
# [400]	training's auc: 0.848614	valid_1's auc: 0.79042
# [500]	training's auc: 0.859488	valid_1's auc: 0.790702
# Early stopping, best iteration is:
# [472]	training's auc: 0.856566	valid_1's auc: 0.790951
# Fold  4 AUC : 0.790951
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.796611	valid_1's auc: 0.769476
# [200]	training's auc: 0.820509	valid_1's auc: 0.781566
# [300]	training's auc: 0.835754	valid_1's auc: 0.785368
# [400]	training's auc: 0.848691	valid_1's auc: 0.786403
# [500]	training's auc: 0.859888	valid_1's auc: 0.786434
# [600]	training's auc: 0.870503	valid_1's auc: 0.786379
# Early stopping, best iteration is:
# [517]	training's auc: 0.86173	valid_1's auc: 0.786543
# Fold  5 AUC : 0.786543
# Full AUC score 0.790646
#    12 | 09m32s |    0.79065 |             0.7254 |           119.8771 |           0.1367 |      60.1944 |      6.8098 |       0.7218 |      0.5510 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.810405	valid_1's auc: 0.773464
# [200]	training's auc: 0.843748	valid_1's auc: 0.784756
# [300]	training's auc: 0.865462	valid_1's auc: 0.787781
# [400]	training's auc: 0.885103	valid_1's auc: 0.788698
# [500]	training's auc: 0.901538	valid_1's auc: 0.788887
# Early stopping, best iteration is:
# [426]	training's auc: 0.889306	valid_1's auc: 0.78923
# Fold  1 AUC : 0.789230
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.808055	valid_1's auc: 0.779998
# [200]	training's auc: 0.841517	valid_1's auc: 0.791184
# [300]	training's auc: 0.862917	valid_1's auc: 0.793504
# [400]	training's auc: 0.882285	valid_1's auc: 0.794292
# [500]	training's auc: 0.899527	valid_1's auc: 0.794473
# Early stopping, best iteration is:
# [481]	training's auc: 0.896635	valid_1's auc: 0.794636
# Fold  2 AUC : 0.794636
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.809963	valid_1's auc: 0.777537
# [200]	training's auc: 0.842392	valid_1's auc: 0.786322
# [300]	training's auc: 0.864974	valid_1's auc: 0.789041
# [400]	training's auc: 0.884293	valid_1's auc: 0.789304
# [500]	training's auc: 0.900825	valid_1's auc: 0.789784
# [600]	training's auc: 0.915771	valid_1's auc: 0.789176
# Early stopping, best iteration is:
# [511]	training's auc: 0.902629	valid_1's auc: 0.790034
# Fold  3 AUC : 0.790034
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.81006	valid_1's auc: 0.777326
# [200]	training's auc: 0.84317	valid_1's auc: 0.787852
# [300]	training's auc: 0.864457	valid_1's auc: 0.790026
# [400]	training's auc: 0.883631	valid_1's auc: 0.790256
# [500]	training's auc: 0.899969	valid_1's auc: 0.790583
# Early stopping, best iteration is:
# [481]	training's auc: 0.896599	valid_1's auc: 0.790895
# Fold  4 AUC : 0.790895
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.809979	valid_1's auc: 0.770252
# [200]	training's auc: 0.842717	valid_1's auc: 0.782599
# [300]	training's auc: 0.864567	valid_1's auc: 0.785023
# [400]	training's auc: 0.883497	valid_1's auc: 0.785888
# [500]	training's auc: 0.89921	valid_1's auc: 0.785514
# Early stopping, best iteration is:
# [429]	training's auc: 0.888241	valid_1's auc: 0.785953
# Fold  5 AUC : 0.785953
# Full AUC score 0.790145
#    13 | 10m58s |    0.79015 |             0.9695 |            44.0895 |           0.0740 |      99.7662 |      8.1230 |       0.5660 |      0.6265 |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.782598	valid_1's auc: 0.766058
# [200]	training's auc: 0.805843	valid_1's auc: 0.781951
# [300]	training's auc: 0.818208	valid_1's auc: 0.787029
# [400]	training's auc: 0.827901	valid_1's auc: 0.789313
# [500]	training's auc: 0.83638	valid_1's auc: 0.790193
# [600]	training's auc: 0.843923	valid_1's auc: 0.790799
# [700]	training's auc: 0.851	valid_1's auc: 0.791383
# [800]	training's auc: 0.857518	valid_1's auc: 0.791856
# Early stopping, best iteration is:
# [790]	training's auc: 0.856889	valid_1's auc: 0.791914
# Fold  1 AUC : 0.791914
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.781056	valid_1's auc: 0.771136
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fc72c263d6a0> in <module>()
# ----> 1 lgbBO.maximize(init_points=2,n_iter=15)
#
# /usr/local/lib/python2.7/dist-packages/bayes_opt/bayesian_optimization.pyc in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     277
#     278             # Append most recently generated values to X and Y arrays
# --> 279             y = self.space.observe_point(x_max)
#     280             if self.verbose:
#     281                 self.plog.print_step(x_max, y, pwarning)
#
# /usr/local/lib/python2.7/dist-packages/bayes_opt/target_space.pyc in observe_point(self, x)
#     137             # measure the target function
#     138             params = dict(zip(self.keys, x))
# --> 139             y = self.target_func(**params)
#     140             self.add_observation(x, y)
#     141         return y
#
# <ipython-input-8-19a93491bcd1> in lgbcv(num_leaves, colsample_bytree, subsample, reg_alpha, reg_lambda, min_split_gain, min_child_weight)
#      22         clf.fit(trn_x, trn_y,
#      23             eval_set= [(trn_x, trn_y), (val_x, val_y)],
# ---> 24             eval_metric='auc', verbose=100, early_stopping_rounds=100  #30
#      25            )
#      26
#
# /usr/local/lib/python2.7/dist-packages/lightgbm/sklearn.pyc in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     673                                         verbose=verbose, feature_name=feature_name,
#     674                                         categorical_feature=categorical_feature,
# --> 675                                         callbacks=callbacks)
#     676         return self
#     677
#
# /usr/local/lib/python2.7/dist-packages/lightgbm/sklearn.pyc in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     467                               verbose_eval=verbose, feature_name=feature_name,
#     468                               categorical_feature=categorical_feature,
# --> 469                               callbacks=callbacks)
#     470
#     471         if evals_result:
#
# /usr/local/lib/python2.7/dist-packages/lightgbm/engine.pyc in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     199                                     evaluation_result_list=None))
#     200
# --> 201         booster.update(fobj=fobj)
#     202
#     203         evaluation_result_list = []
#
# /usr/local/lib/python2.7/dist-packages/lightgbm/basic.pyc in update(self, train_set, fobj)
#    1522             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1523                 self.handle,
# -> 1524                 ctypes.byref(is_finished)))
#    1525             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1526             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
lgbBO.res['max']
# Out:
# {'max_params': {'colsample_bytree': 0.5802478232647209,
#   'min_child_weight': 20.33692569448104,
#   'min_split_gain': 0.7649917884568475,
#   'num_leaves': 21.152379900895014,
#   'reg_alpha': 9.756996480309178,
#   'reg_lambda': 8.776694575019713,
#   'subsample': 0.9370453331986632},
#  'max_val': 0.793068381666508}

# %%
colsample_bytree |   min_child_weight |   min_split_gain |   num_leaves |   reg_alpha |   reg_lambda |   subsample |
